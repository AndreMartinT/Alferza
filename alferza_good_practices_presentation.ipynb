# %% [markdown]
# ![alferza%20image_2.jfif](attachment:alferza%20image_2.jfif)

# %% [markdown]
# # Perfil del Analista de Datos Para ALFERZA
#
# El analista de datos o **Big Data Analyst** es encargado de:
#
# + EXTRAER
# + ANALIZAR estadísticamente
# + PROCESAR grandes cantidades de datos **cuantitativos y cualitativos**
#
#
# **Transformar la data en información.**

# %% [markdown]
# ![Datos-info-conocimiento-2.png](attachment:Datos-info-conocimiento-2.png)

# %% [markdown]
# ### CARACTERISITCAS IMPORTANTES:
#
# + Manejo de herramientas de extracción y manipulación de datos
# + Diseño y visualización de datos
# + **TENER VISION DEL NEGOCIO**
# + Capacidad de análisis y síntesis
# + Creatividad y pensamiento crítico

# %% [markdown]
# ![2022-08-16_11-23-54.png](attachment:2022-08-16_11-23-54.png)

# %% [markdown]
# ### CONOCIMIENTOS EN:
# + Matemáticas
# + Estadística
# + Big Data
# + Analítica web
# + Lenguajes de programación y bases de datos:
#     + Python, R, Tableau, PowerBI, Google Analytics, etc.
#     + SQL
#     + **EXCEL**
#     + **SPERANT**

# %% [markdown]
# ## En ALFERZA, los objetivos principales son:
#
# + Conocer a los clientes, caracteristicas, hábitos de compra, etc.
# + Proporcionar informacion relevante a la empresa para la toma de decisiones y alcanzar sus objetivos estratégicos:
#         + Dar a conocer sus productos: CASTILLA - RECOLETA - OTROS
#         + Aumentar las ventas: AUMENTAR LEADS Y LA CALIDAD DE LOS MISMOS
#         + Reducir los costes: ENCONTRAR LOS NICHOS DE MERCADO, DE ACUERDO AL PERFIL DEL CONSUMIDOR DE LA EMPRESA
#         + Mantener la rentabilidad del negocio, entre otros.
#
# + Con una base de datos limpia y con informacion relevante del negocio y del mercado, y con machine learning uno puede:
#         + Hacer analisis de sentimientos (nube de palabras)
#         + Analisis de clientes potenciales
#         + Analisis churn (abandono de clientes)
#         + Segmentacion de mercados (tipo de cliente por proyecto)
#         + Mucho mas...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.chdir('C:\\Users\\Lenovo\\Desktop\\1 Alferza_\\Base_datos')

# %% [markdown]
# ![minsa.jfif](attachment:minsa.jfif)

# %%
minsa = pd.read_excel('minsa_conglomerado_jun_2022.xlsx')
minsa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20924 entries, 0 to 20923
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PK_ID_PERSONAL           20924 non-null  int64
#  1   VC_PERSONAL_RUC_ENTIDAD  20924 non-null  int64
#  2   VC_PERSONAL_PATERNO      20924 non-null  object
#  3   VC_PERSONAL_MATERNO      20924 non-null  object
#  4   VC_PERSONAL_NOMBRES      20924 non-null  object
#  5   VC_PERSONAL_CARGO        20924 non-null  object
#  6   VC_PERSONAL_DEPENDENCIA  20924 non-null  object
#  7   MO_PERSONAL_TOTAL        20924 non-null  float64
#  8   FECHA_REG                20924 non-null  datetime64[ns]
#  9   REGIMEN_LABORAL          20924 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 1.6+ MB

# %% [markdown]
# ![logo-unsa.png](attachment:logo-unsa.png)

# %%
unsa = pd.read_excel('from_unsa_to_alferza_db.xlsx')
unsa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1578 entries, 0 to 1577
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nro           1578 non-null   int64
#  1   nombre        1578 non-null   object
#  2   dni           1556 non-null   float64
#  3   institucion   1578 non-null   object
#  4   area          1578 non-null   object
#  5   facultad      1578 non-null   object
#  6   departamento  1578 non-null   object
#  7   cargo         1578 non-null   object
#  8   correo_65     1575 non-null   object
#  9   correo_30     1575 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 123.4+ KB

# %% [markdown]
# # Las principales funciones y metas del analista de datos en ALFERZA son:
#
# ### Metas a mediano y largo plazo
#
# #### 1. Recopilar los datos en un solo repositorio
#
# 1.1. Para manipular los datos y hacer analisis, se requiere de **BUENAS PRACTICAS** en el llenado de datos, cuando las tablas de excel ya no son funcionales, significa que se deben trabajar con otras soluciones, o encontrar soluciones practicas.
# * Crear tablas para los diversos procesos de la empresa
# * Crear formularios para solicitar la informacion relebante
# * Limpiar y actualizar la data de ventas y visitas

# %% [markdown]
# ![db%20relaciones.png](attachment:db%20relaciones.png)

# %%
castilla = pd.read_excel('oficial ventas castilla.xlsx')
castilla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 94 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   cliente_nro_documento               36 non-null     int64
#  1   cliente_nombre                      36 non-null     object
#  2   cliente_apellido                    36 non-null     object
#  3   cliente_celular                     36 non-null     int64
#  4   cliente_correo                      36 non-null     object
#  5   cliente_direccion                   36 non-null     object
#  6   cliente_link_busqueda               1 non-null      object
#  7   cliente_edad                        36 non-null     int64
#  8   cliente_fecha_naciemiento           34 non-null     datetime64[ns]
#  9   cliente_genero                      36 non-null     object
#  10  cliente_estado_civil                36 non-null     object
# ...

# %% [markdown]
# 1.2. **Analizar e identificar datos interesantes** de cara a optimizar la gestión empresarial y estrategia de negocio. Procesar los datos, extraer el valor y sacar conclusiones/hipótesis que servirán de base para las estrategias que se implementarán.
#
# + Las principales fuentes EN EL AREA DE VENTAS Y MKT son:
#     + DRIVE COMPARTIDO (REPORTE DE VISITAS) reporte mas completo, necesita nuevo formato
#     + EXCEL VENTAS reporte interno mas detallado de compradores
#     + SPERANT base de datos exportada
#         - 26000 registros aprox.
#         - Datos faltantes
#         - Columnas que se desconoce el origen
#         - Reporte de descarga incompleta
#     + SPERANT CRM

# %% [markdown]
# ![excel%20img.jpg](attachment:excel%20img.jpg)

# %% [markdown]
# 1.3. **Generar informes** y presentarlos ante los directivos de la empresa o los responsables del departamento correspondiente
#
# + Solicitar acceso a toda la informacion relevante que la empresa desee analizar
#     + INTRANET: LD-GRUPOS
#     + EXTRANET: Pagina Web de ALFERZA
#     + DRIVE COMPARTIDO
#     + SPERANT con acceso de administrador
#     + [SPERANT](https://sperant.com/#clientes) tiene un servicio de Business Inteligente

# %% [markdown]
# ![2022-08-16_11-44-36.png](attachment:2022-08-16_11-44-36.png)

# %% [markdown]
# #### Extra
# Empresas que lidian con grandes volumenes de informacion migran sus bases de datos a soluciones donde puedan malipularse estos volumenes de datos (**AWS Amazon, AZURE Microsoft, Google Cloud, etc.**), lo ideal es trabajar con **SQL**.
# * Crear la base de datos en SQL
# * Capacitar al personal en este lenguaje de consultas de bases de datos

# %% [markdown]
# ![python%20logo.png](attachment:python%20logo.png)

# %% [markdown]
# ### Python_buenas_practicas
# [Link to WebSide](https://peps.python.org/pep-0008/)

# %% [markdown]
# ### The Zen of Python

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ![guido%20rossum.jfif](attachment:guido%20rossum.jfif)
# **Guido van Rossum** - autor del lenguaje de programación Python

# %% [markdown]
# ### Revisemos algunos puntos

# %% [markdown]
# **Beautiful is better than ugly**

# %%
print('hola alferza')
print(len('hola alferza'))
# Out:
# hola alferza
# 12

# %%
print(len(input()))
# Out:
# HOLA ALFERZA
# 12

# %% [markdown]
# **Explicit is better than implicit**
# - Simple is better than complex
# - Complex is better than complicated
# - **Flat is better than nested**

# %%
campania = ['2207 Recoleta // ubicacion sala de bentas']

# %%
campania = {'nombre campaña':'Ubicacion sala de ventas':{'proyecto':{'recoleta':{'anio':{2202:{'mes':'julio'}}}}}}

# %%
campania = ['Ubicacion sala de ventas']
proyecto = ['Recoleta']
anio = [2022]
mes = ['Julio']
# EXCEL

# %% [markdown]
# - Sparse is better than dense
# - **Readability counts**

# %%
comentario = ['cliente dijo que quedaria pendiente el pago a realizar por temas X']

# %% [markdown]
# **In the face of ambiguity, refuse the temptation to guess**

# %%
espacio_blanco = ' '
sin_caracter = ''
no_valor_cero= ' '
valor_cero = 0

# %%
espacio_blanco == valor_cero
# Out:
# False

# %% [markdown]
# - If the implementation is hard to explain, it's a bad idea.
# - If the implementation is easy to explain, it may be a good idea.

# %% [markdown]
# ![data_cleaning_4.jfif](attachment:data_cleaning_4.jfif)

# %% [markdown]
# ### Extra, pero muy importante!
#
# #### Tipos de datos
# * No nos interesa todos

# %%
## INTEGER
## FLOAT 
## STRINGS
## SETS
## TUPLES
## BOOLEANS
## LIST
## DICT

# %% [markdown]
# * Nos interesa!
#
# ### Integers
#
# * datos numericos
#     * numero, hora, monto, etc.
#
# ###  Strings
#
# * datos que contienen texto
#     * categoricos: pueden ser agrupado como el area geografica, nivel socioeconomico, usuario vendedor, proyecto, etc.
#     * no categoricos: ejemplo, correos, comentarios, etc.

# %% [markdown]
# ![nod.png](attachment:nod.png)

# %% [markdown]
# - **Keep it simple s!**
# - **Think everybody is dump, be as clear as possible!**
# - **Adaptation to change**

# %% [markdown]
# ![2022-08-16_11-25-42.png](attachment:2022-08-16_11-25-42.png)
